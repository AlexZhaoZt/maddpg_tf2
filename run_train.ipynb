# %%
import os
import sys
#from tensorflow.python.framework.ops import disable_eager_execution
#disable_eager_execution()
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
new_path = r'C:\Users\Alex Zhao\Desktop\CCR'

sys.path.append(new_path) 
# %run train.py --scenario simple --display
# Out:
# Using good policy maddpg and adv policy maddpg
# Loading previous state...
# Starting iterations...
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Desktop\maddpg_tf2\train.py in <module>
#     176 if __name__ == '__main__':
#     177     arglist = parse_args()
# --> 178     train(arglist)
#
# ~\Desktop\maddpg_tf2\train.py in train(arglist)
#     135         if arglist.display:
#     136             time.sleep(0.1)
# --> 137             env.render()
#     138             continue
#     139
#
# ~\Desktop\CCR\multiagent\environment.py in render(self, mode)
#     260                 self.render_geoms_xform[e].set_translation(*entity.state.p_pos)
#     261             # render to display or array
# --> 262             results.append(self.viewers[i].render(return_rgb_array = mode=='rgb_array'))
#     263
#     264         return results
#
# ~\Desktop\CCR\multiagent\rendering.py in render(self, return_rgb_array)
#     108             arr = arr.reshape(buffer.height, buffer.width, 4)
#     109             arr = arr[::-1,:,0:3]
# --> 110         self.window.flip()
#     111         self.onetime_geoms = []
#     112         return arr
#
# Z:\Anaconda\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     336                     _dwmapi.DwmFlush()
#     337
# --> 338         self.context.flip()
#     339
#     340     def set_location(self, x, y):
#
# AttributeError: 'NoneType' object has no attribute 'flip'
